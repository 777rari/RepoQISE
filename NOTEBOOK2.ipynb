# %%
# Hi this text is the header for my quantum notebook
More text in here that would later describe the contents of the notebook.
1. You can make things **bold**
2. You can have links [link_to_google](https://google.com)

# %%
2+2
# Out:
# 4

# %%
import qiskit

# %%
c1=3+4j
c2=5+6j
c3=c1+c2

# %%
print(c3)
# Out:
# (8+10j)

# %% [markdown]
# # Section 2
# Present more features

# %%
import math
import numpy as np
a=np.linspace(0,2*math.pi, 20)
b=np.sin(a)

# %%
import matplotlib.pyplot as plt
plt.plot(a,b)

# %%
#This is token--->

# %% [markdown]
# # Formualate Python Code to be able to Construct Game

# %% [markdown]
# # Usage instructions For User Interface

# %%
print('1. Write instructions here')
print('     A. Describe functions on interface')
# Out:
# 1. Write instructions here
#      A. Describe functions on interface
